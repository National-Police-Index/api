# %%
import pandas as pd

# %%
# def read_tbl():
#     df = pd.read_csv("../data/input/involved_officers_2-2-2026.csv")
#     df = df[df.source_agency.astype(str).str.lower().str.contains("corrections")]
#     # df = df[~((df.incident_date.fillna("") == ""))]
#     return df 


# df = read_tbl()
# df

# %%
def read_tbl():
    df = pd.read_csv("../data/output/post_export.csv")
    df = df[df.agency_name.astype(str).str.lower().str.contains("corrections")]
    # df = df[~((df.incident_date.fillna("") == ""))]
    return df 


df = read_tbl()
df
# Out:
#        person_nbr  first_name middle_name   last_name  \
# 23000      259591       NARDA           A      MOLINA
# 23001      259592  ANTONIO JR         NaN  ARMENDARIZ
# 23002      259612        HUGH           D       TYSON
# 23003      259615       ISAAC           S       GOMEZ
# 23004      259616     ERNESTO           N      CHAVEZ
# ...           ...         ...         ...         ...
# 578995     246942      DANIEL           A  RICHARDSON
# 578996     246943     MARIANA         NaN       REYES
# 578997     246945     VINCENT           E    VILLEGAS
# 578998     246946     ALFREDO         NaN   UGARTE JR
# 578999     246947      ADAUTO         NaN    FIGUEROA
#
#                                               agency_name  start_date  \
# 23000   048: RA MCGEE CORRECTIONS TRAIN CENTER -AKA- R...  2016-05-10
# 23001   048: RA MCGEE CORRECTIONS TRAIN CENTER -AKA- R...  2006-09-25
# 23002   048: RA MCGEE CORRECTIONS TRAIN CENTER -AKA- R...  2008-03-10
# ...
