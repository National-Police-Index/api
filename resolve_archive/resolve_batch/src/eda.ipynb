# %%
import pandas as pd

# %%
# def read_tbl():
#     df = pd.read_csv("../data/output/df.csv")
#     return df 


# df = read_tbl()

# df_new = df.copy()
# df_new = df_new.sample(n=100)

# # df_new.to_csv("../data/output/review.csv", index=False)

# %%
# def read_post():
#     df = pd.read_csv("../../preprocess/data/output/post.csv")
#     return df 

# post = read_post()

# post = post[post.person_nbr.fillna("").str.contains(r"B36-D90")]

# post

# %%
# df = pd.read_csv("data/output/df.csv")
# df = df[~((df.post_uid.fillna("") == ""))]
# # df = df[df.source_agency.str.lower().str.contains(r"district|redding|san fran|fullerton|orange|contra|riverside|siski|ontario")]
# # df.to_csv("data/output/review.csv", index=False)
# # df.to_csv("data/output/review.csv", index=False)

# df.to_csv("data/output/df.csv", index=False)

# %%
df = pd.read_csv("../data/input/involved_officers.csv")

df

# df = df[~(df.last_name.fillna("") == "")]

# df = df[~(df.first_name.fillna("") == "")]

# df.to_csv("data/output/df_clean.csv", index=False)
# Out:
#        Unnamed: 0                            resourceid provisional_case_name  \
# 0               0  e3d5ea42-a9ee-40a8-9086-d5b32eedf15d     1740951640826-zkk
# 1               1  7d7b8afc-3aeb-4184-a7ad-7d4effb17cb8     1718348692268-hwz
# 2               2  d3344174-b769-465d-a7bc-3552209cd1a4     1742346852942-eui
# 3               3  e975c70e-adc8-491b-a175-479d30ce00cd     1736837540578-kgx
# 4               4  e045c903-3a78-4c8b-8a38-e3987dac8fec     1737931023611-xwj
# ...           ...                                   ...                   ...
# 21069       21069  54e9e554-376d-4f3c-bc61-a706444145f6     1742471240489-oqn
# 21070       21070  54e9e554-376d-4f3c-bc61-a706444145f6     1742471240489-oqn
# 21071       21071  54e9e554-376d-4f3c-bc61-a706444145f6     1742471240489-oqn
# 21072       21072  54e9e554-376d-4f3c-bc61-a706444145f6     1742471240489-oqn
# 21073       21073  54e9e554-376d-4f3c-bc61-a706444145f6     1742471240489-oqn
#
#             roles first_name  last_name middle_name suffix  num_citations  \
# 0      Used Force    DOMINIC   DEGUILIO         NaN    NaN              3
# 1      Used Force        DON       DODT         NaN    NaN              3
# 2      Used Force     DONNIE    JOHNSON         NaN    NaN              3
# 3      Used Force   NICHOLAS     WEAVER         NaN    NaN              3
# 4      Used Force    DOUGLAS       ELMS         NaN    NaN              3
# ...           ...        ...        ...         ...    ...            ...
# 21069  Used Force     MARISA    PERALEZ         NaN    NaN              3
# 21070  Used Force      NANCY  RODRIGUEZ         NaN    NaN              3
# 21071  Used Force   NICHOLAS    VELASCO         NaN    NaN              3
# 21072  Used Force      RUBEN      MEJIA         NaN    NaN              3
# 21073  Used Force       VITO   NARDULLI         NaN    NaN              3
#
#        incident_year  incident_month  incident_day  \
# 0               2017               4             4
# 1               2008               5             8
# 2               2014               6            25
# 3               2018               2             7
# 4               2014               9            19
# ...              ...             ...           ...
# 21069           2021               7            26
# 21070           2021               7            26
# 21071           2021               7            26
# 21072           2021               7            26
# 21073           2021               7            26
#
#                        source_agency  \
# 0             NAPA POLICE DEPARTMENT
# 1           UPLAND POLICE DEPARTMENT
# 2         LOS ANGELES COUNTY SHERIFF
# 3              SHASTA COUNTY SHERIFF
# 4          ANAHEIM POLICE DEPARTMENT
# ...                              ...
# 21069  LOS ANGELES POLICE DEPARTMENT
# 21070  LOS ANGELES POLICE DEPARTMENT
# 21071  LOS ANGELES POLICE DEPARTMENT
# 21072  LOS ANGELES POLICE DEPARTMENT
# 21073  LOS ANGELES POLICE DEPARTMENT
#
#                                       mentioned_agencies agency_type
# 0      California Highway Patrol, Napa County Distric...      POLICE
# 1      Chino Police Department, Ontario Police Depart...      POLICE
# 2      Los Angeles County Sheriff's Department, San B...      POLICE
# 3      Redding Police Department, Shasta County Sheri...      POLICE
# 4      Anaheim Police Department, California Highway ...      POLICE
# ...                                                  ...         ...
# 21069                      Los Angeles Police Department      POLICE
# 21070                      Los Angeles Police Department      POLICE
# 21071                      Los Angeles Police Department      POLICE
# 21072                      Los Angeles Police Department      POLICE
# 21073                      Los Angeles Police Department      POLICE
#
# [21074 rows x 15 columns]

# %%
# df = pd.read_csv("data/output/df.csv")
# df = df[~((df.match_probability.fillna("") == ""))]

# def analyze_probabilities(df):
#     """Analyze the distribution of match_probability column"""
#     probs = df['match_probability'].dropna()
    
#     print(f"Total records: {len(probs)}")
#     print(f"\nBasic stats:")
#     print(f"  Mean: {probs.mean():.3f}")
#     print(f"  Median: {probs.median():.3f}")
#     print(f"  Std Dev: {probs.std():.3f}")
#     print(f"  Min: {probs.min():.3f} | Max: {probs.max():.3f}")
    
#     print(f"\nPercentiles:")
#     for p in [25, 50, 75, 90, 95, 99]:
#         print(f"  {p}th: {probs.quantile(p/100):.3f}")
    
#     print(f"\nBinned distribution:")
#     bins = [0, 0.5, 0.7, 0.8, 0.9, 0.95, 1.0]
#     counts = pd.cut(probs, bins=bins, include_lowest=True).value_counts().sort_index()
#     for bin_range, count in counts.items():
#         pct = count / len(probs) * 100
#         print(f"  {bin_range}: {count:,} ({pct:.1f}%)")

# analyze_probabilities(df)

# %%
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
# import numpy as np
# from scipy import stats

# def analyze_probabilities(df):
#     """Analyze the distribution of match_probability column with visualizations"""
#     probs = df['match_probability'].dropna()
    
#     print("=" * 60)
#     print("MATCH PROBABILITY ANALYSIS")
#     print("=" * 60)
#     print(f"\n📊 Total matches analyzed: {len(probs):,}")
    
#     print(f"\n📈 SUMMARY STATISTICS")
#     print(f"   Average probability: {probs.mean():.1%}")
#     print(f"   Middle value (median): {probs.median():.1%}")
#     print(f"   Spread (std dev): {probs.std():.3f}")
#     print(f"   Range: {probs.min():.1%} to {probs.max():.1%}")
    
#     print(f"\n🎯 KEY THRESHOLDS")
#     print(f"   25% of matches are below: {probs.quantile(0.25):.1%}")
#     print(f"   50% of matches are below: {probs.quantile(0.50):.1%}")
#     print(f"   75% of matches are below: {probs.quantile(0.75):.1%}")
#     print(f"   90% of matches are below: {probs.quantile(0.90):.1%}")
#     print(f"   95% of matches are below: {probs.quantile(0.95):.1%}")
    
#     print(f"\n📦 CONFIDENCE GROUPS")
#     bins = [0, 0.5, 0.7, 0.8, 0.9, 0.95, 1.0]
#     labels = ['Low (<50%)', 'Medium (50-70%)', 'Good (70-80%)', 
#               'High (80-90%)', 'Very High (90-95%)', 'Excellent (95%+)']
#     counts = pd.cut(probs, bins=bins, include_lowest=True).value_counts().sort_index()
    
#     for (bin_range, count), label in zip(counts.items(), labels):
#         pct = count / len(probs) * 100
#         bar = '█' * int(pct / 2)  # Visual bar
#         print(f"   {label:20s}: {count:6,} ({pct:5.1f}%) {bar}")
    
#     # Create subplots
#     fig = make_subplots(
#         rows=1, cols=2,
#         subplot_titles=(
#             'Box Plot: What does the spread look like?', 
#             'Distribution: How are probabilities clustered?'
#         )
#     )
    
#     # Box and whisker plot
#     fig.add_trace(
#         go.Box(
#             y=probs, 
#             marker_color='lightblue',
#             boxmean='sd',
#             hovertemplate='<b>Value: %{y:.1%}</b><extra></extra>',
#             showlegend=False  # Remove from legend
#         ),
#         row=1, col=1
#     )
    
#     # Simple histogram showing actual distribution
#     fig.add_trace(
#         go.Histogram(
#             x=probs, 
#             marker_color='steelblue', 
#             opacity=0.8,
#             nbinsx=30,
#             hovertemplate='Probability: %{x:.1%}<br>Count: %{y}<extra></extra>',
#             showlegend=False  # Remove from legend
#         ),
#         row=1, col=2
#     )
    
#     # Update layout
#     fig.update_xaxes(title_text="Match Probability", tickformat='.0%', row=1, col=2)
#     fig.update_yaxes(title_text="Match Probability", tickformat='.0%', row=1, col=1)
#     fig.update_yaxes(title_text="Number of Matches", row=1, col=2)
    
#     fig.update_layout(
#         height=550,
#         showlegend=False,  # Hide legend entirely since it's not needed
#         title_text="<b>Match Probability Distribution Analysis</b><br>",
#         title_x=0.5,
#         font=dict(size=12),
#         hovermode='closest'
#     )
    
#     fig.show()
    
#     print("\n" + "=" * 60)

# analyze_probabilities(df)
